# %% [markdown]
# <a href="https://colab.research.google.com/github/Eakansh249120/THAPAR_MINI_PROJECT7/blob/main/THAPAR_MINI_PROJECT7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
marks_df=pd.read_csv('Marks.csv')
marks_df

#marks_df.value_counts().head()
total_marks= marks_df.groupby('Roll Num').sum().reset_index().sort_values('Roll Num')
total_marks.to_csv('total_marks.csv',index=False)
